# %% [markdown]
# # Analysis of Anger in Posts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, levene
from itertools import combinations
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm

# %% [markdown]
# Load data and specify dependent and independent variables

# %%
pd.set_option('display.float_format', '{:.8f}'.format)

sentiments = pd.read_csv(
    "combined_sentiments.csv", 
    keep_default_na=False,  # Prevents default strings (like 'None', 'NA') from becoming NaN
    na_values=['']          # Optional: Specify that only empty strings should be NaN
)

dv = "anger_p"
iv1 = "dominant_emotion_a"
iv2 = "NewsroomTopic"

# %% [markdown]
# Choose if you want to do a logit transformation

# %%
logit_transformation = False

if logit_transformation:
    sentiments['anger_p_logit'] = np.log((sentiments[dv]) / (1 - sentiments[dv]))
    dv_use = 'anger_p_logit'
    
    compare_logit = sentiments[['anger_p', 'anger_p_logit']]

    print(f'max: {max(compare_logit['anger_p'])}')
    print(f'min: {min(compare_logit['anger_p'])}')
    print(f'max logit: {max(compare_logit['anger_p_logit'])}')
    print(f'min logit: {min(compare_logit['anger_p_logit'])}')
    
    compare_logit.head()
else:
    dv_use = dv
    print(f'max: {max(sentiments['anger_p'])}')
    print(f'min: {min(sentiments['anger_p'])}')
# Out:
# max: 0.9972729086875916
# min: 2.2472344426205385e-05

# %% [markdown]
# Check distributions of anger in posts across dominant emotions of articles

# %%
for level in sentiments[iv1].unique():
    group_data = sentiments.loc[sentiments[iv1] == level, dv_use]
    if len(group_data) >= 3:
        stat, p = shapiro(group_data)
        print(f"{iv1}={level}: W={stat:.4f}, p={p:.4f}")
        
        plt.figure(figsize=(6,4))
        sns.histplot(group_data, bins=20, kde=True, color='skyblue')
        plt.title(f"{dv_use} distribution for {iv1} = {level}")
        plt.xlabel(dv_use)
        plt.ylabel("Count")
        plt.show()
# Out:
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 100121.
#   res = hypotest_fun_out(*samples, **kwds)
# dominant_emotion_a=Fear: W=0.7852, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 19906.
#   res = hypotest_fun_out(*samples, **kwds)
# dominant_emotion_a=None: W=0.7956, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9333.
#   res = hypotest_fun_out(*samples, **kwds)
# dominant_emotion_a=Anger: W=0.7882, p=0.0000
# dominant_emotion_a=Sadness: W=0.7791, p=0.0000
# dominant_emotion_a=Joy: W=0.8034, p=0.0000
# dominant_emotion_a=Disgust: W=0.7989, p=0.0000

# %% [markdown]
# Check distributions of anger in posts across topics of articles

# %%
for level in sentiments[iv2].unique():
    group_data = sentiments.loc[sentiments[iv2] == level, dv_use]
    if len(group_data) >= 3:
        stat, p = shapiro(group_data)
        print(f"{iv2}={level}: W={stat:.4f}, p={p:.4f}")
        
        # Plot distribution
        plt.figure(figsize=(6,4))
        sns.histplot(group_data, bins=20, kde=True, color='salmon')
        plt.title(f"{dv_use} distribution for {iv2} = {level}")
        plt.xlabel(dv_use)
        plt.ylabel("Count")
        plt.show()
# Out:
# NewsroomTopic=User: W=0.7813, p=0.0000
# NewsroomTopic=Wissenschaft: W=0.7788, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 12979.
#   res = hypotest_fun_out(*samples, **kwds)
# NewsroomTopic=Web: W=0.7905, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 20958.
#   res = hypotest_fun_out(*samples, **kwds)
# NewsroomTopic=International: W=0.7862, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 29642.
#   res = hypotest_fun_out(*samples, **kwds)
# NewsroomTopic=Panorama: W=0.7859, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 26510.
#   res = hypotest_fun_out(*samples, **kwds)
# NewsroomTopic=Inland: W=0.7823, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9127.
#   res = hypotest_fun_out(*samples, **kwds)
# NewsroomTopic=Sport: W=0.7999, p=0.0000
# C:\Users\vince\miniconda3\envs\datascience\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 20980.
#   res = hypotest_fun_out(*samples, **kwds)
# NewsroomTopic=Wirtschaft: W=0.7870, p=0.0000
# NewsroomTopic=Etat: W=0.7856, p=0.0000
# NewsroomTopic=Kultur: W=0.7736, p=0.0000

# %% [markdown]
# Choose if you want to remove statistical outliers and a threshold for extreme residuals

# %%
remove_extremes = False
threshold = 0.001

# %%
def remove_outliers():

    print(f"Initial observations: {len(sentiments)}")

    counts_before = sentiments.groupby([iv2, iv1]).size().unstack(fill_value=0)
    counts_before['Total'] = counts_before.sum(axis=1)
    counts_before.loc['Total'] = counts_before.sum(axis=0)
    print("\nCounts of each NewsroomTopic x dominant_emotion_a BEFORE filtering:")
    print(counts_before)

    if remove_extremes:
        formula_init = f"{dv_use} ~ C({iv1}) + C({iv2})"
        model_init = smf.ols(formula_init, data=sentiments).fit()
        residuals_init = model_init.resid.reindex(sentiments.index)
        
        lower = residuals_init.quantile(threshold)
        upper = residuals_init.quantile(1 - threshold)
        
        mask = residuals_init.between(lower, upper)
        test_data = sentiments.loc[mask].copy()
        
        print(f"\nRemoved top and bottom {threshold} of extreme residuals: kept {len(test_data)} observations")

        counts_after = test_data.groupby([iv2, iv1]).size().unstack(fill_value=0)
        counts_after['Total'] = counts_after.sum(axis=1)
        counts_after.loc['Total'] = counts_after.sum(axis=0)
        print("\nCounts of each NewsroomTopic x dominant_emotion_a AFTER filtering:")
        print(counts_after)

    else:
        test_data = sentiments
        print("\nNo extreme residuals removed; using full dataset")

    return test_data

test_data = remove_outliers()
# Out:
# Initial observations: 131548
#
# Counts of each NewsroomTopic x dominant_emotion_a BEFORE filtering:
# dominant_emotion_a  Anger  Disgust    Fear  Joy   None  Sadness   Total
# NewsroomTopic
# Etat                  731        8    1830   18    611        7    3205
# Inland               2740        0   19616   63   4091        0   26510
# International         594      117   17430    1   2685      131   20958
# Kultur                 58        0    1196   25    127       68    1474
# Panorama             1371      427   23413   58   3635      738   29642
# Sport                 465        1    4015  223   4271      152    9127
# User                   39        0    3354   19     11       14    3437
# Web                  1483        0    9357   15   2112       12   12979
# Wirtschaft           1837        0   17052    0   2074       17   20980
# Wissenschaft           15        0    2858   69    289        5    3236
# Total                9333      553  100121  491  19906     1144  131548
#
# No extreme residuals removed; using full dataset

# %% [markdown]
# Check for homoskedacity of variances whitin main factors

# %%
def levene_test(iv):

    groups = [test_data.loc[test_data[iv] == lvl, dv_use] for lvl in test_data[iv].unique()]

    stat, p = levene(*groups, center='median')
    print(f"Levene test for equal variances across {iv}:")

    if p < 0.05:
        print(f"  → ANOVA assumption of homoscedasticity is VIOLATED for {iv}.")
    else:
        print(f"  → ANOVA assumption of homoscedasticity is OK for {iv}.")

levene_test(iv1)
levene_test(iv2)
# Out:
# Levene test for equal variances across dominant_emotion_a:
#   → ANOVA assumption of homoscedasticity is VIOLATED for dominant_emotion_a.
# Levene test for equal variances across NewsroomTopic:
#   → ANOVA assumption of homoscedasticity is VIOLATED for NewsroomTopic.

# %% [markdown]
# Perform bootstrapped testings to correct for violations of assumptions

# %%
random_state = 12
alpha = 0.001
n_boot = 1000

# %% [markdown]
# 1. ANOVA with bootstrapped eta_p2

# %% [markdown]
# Significane Labels are retrieved from confidence intervals of eta_p2 that exclude 0

# %%
def bootstrap_anova():

    np.random.seed(random_state)

    formula = f"{dv_use} ~ C({iv1}) + C({iv2})"
    model = smf.ols(formula, data=test_data).fit()

    anova_df = anova_lm(model, typ=2).reset_index()
    ss_error = anova_df.loc[anova_df['index'] == 'Residual', 'sum_sq'].values[0]
    df_error = int(model.df_resid)

    results_list = []

    for _, row in anova_df.iterrows():
        effect = row['index']
        if effect == 'Residual':
            continue

        df_effect = int(row['df'])
        F_orig = row['F']
        eta_p2_orig = row['sum_sq'] / (row['sum_sq'] + ss_error)

        boot_eta = []
        for _ in range(n_boot):
            df_boot = test_data.sample(n=len(test_data), replace=True)
            model_boot = smf.ols(formula, data=df_boot).fit()
            anova_boot = anova_lm(model_boot, typ=2)
            ss_error_boot = anova_boot.loc['Residual', 'sum_sq']
            ss_effect_boot = anova_boot.loc[effect, 'sum_sq']
            eta_p2_boot = ss_effect_boot / (ss_effect_boot + ss_error_boot)
            boot_eta.append(eta_p2_boot)

        ci_lower = np.percentile(boot_eta, 100 * (alpha / 2))
        ci_upper = np.percentile(boot_eta, 100 * (1 - alpha / 2))

        significant = (ci_lower > 0) or (ci_upper < 0)

        results_list.append({
            "effect": effect,
            "F": F_orig,
            "eta_p2": eta_p2_orig,
            "eta_p2_ci_lower": ci_lower,
            "eta_p2_ci_upper": ci_upper,
            "df_effect": df_effect,
            "df_error": df_error,
            "significant": significant
        })

    return pd.DataFrame(results_list)

# %%
anova_results = bootstrap_anova()
anova_results
# Out:
#                   effect           F     eta_p2  eta_p2_ci_lower  \
# 0  C(dominant_emotion_a) 39.63583270 0.00142778       0.00082393
# 1       C(NewsroomTopic) 61.11176546 0.00493575       0.00383009
#
#    eta_p2_ci_upper  df_effect  df_error  significant
# 0       0.00221265          4    110883         True
# 1       0.00623497          9    110883         True

# %% [markdown]
# 2. Post Hoc tests

# %% [markdown]
# Significane Labels are retrieved from confidence intervals of mean differences that exclude 0

# %%
def bootstrap_pairwise(iv):

    np.random.seed(random_state)

    levels = test_data[iv].unique()
    combs = list(combinations(levels, 2))
    results = []

    for a, b in combs:
        data_a = test_data[test_data[iv] == a][dv_use].values
        data_b = test_data[test_data[iv] == b][dv_use].values

        mean_a = data_a.mean()
        mean_b = data_b.mean()
        mean_diff = mean_a - mean_b

        diff_boot = []
        for _ in range(n_boot):
            sample_a = np.random.choice(data_a, size=len(data_a), replace=True)
            sample_b = np.random.choice(data_b, size=len(data_b), replace=True)
            diff_boot.append(sample_a.mean() - sample_b.mean())

        ci_lower = np.percentile(diff_boot, 100 * (alpha / 2))
        ci_upper = np.percentile(diff_boot, 100 * (1 - alpha / 2))

        significant = (ci_lower > 0) or (ci_upper < 0)

        results.append({
            "group_a": a,
            "group_b": b,
            "mean_a": mean_a,
            "mean_b": mean_b,
            "mean_diff": mean_diff,
            "ci_lower": ci_lower,
            "ci_upper": ci_upper,
            "significant": significant
        })

    return pd.DataFrame(results)

# %% [markdown]
# Pairwise comparison of emotions

# %%
emotion_results = bootstrap_pairwise(iv1)
emotion_results
# Out:
#    group_a  group_b      mean_a      mean_b   mean_diff    ci_lower  \
# 0     Fear    Anger -0.95315981 -0.28885451 -0.66430530 -0.81618253
# 1     Fear  Sadness -0.95315981 -1.42840116  0.47524135  0.05583723
# 2     Fear      Joy -0.95315981 -1.17594287  0.22278306 -0.29169736
# 3     Fear  Disgust -0.95315981 -0.50812799 -0.44503182 -1.07514390
# 4    Anger  Sadness -0.28885451 -1.42840116  1.13954665  0.75886166
# 5    Anger      Joy -0.28885451 -1.17594287  0.88708835  0.27144561
# 6    Anger  Disgust -0.28885451 -0.50812799  0.21927347 -0.37817914
# 7  Sadness      Joy -1.42840116 -1.17594287 -0.25245829 -1.12349778
# 8  Sadness  Disgust -1.42840116 -0.50812799 -0.92027318 -1.64938274
# 9      Joy  Disgust -1.17594287 -0.50812799 -0.66781488 -1.53062435
#
#      ci_upper  significant
# 0 -0.52721617         True
# 1  0.91352292         True
# 2  0.86044732        False
# 3  0.06966438        False
# 4  1.53718377         True
# 5  1.41342401         True
# 6  0.75529126        False
# 7  0.48074513        False
# 8 -0.24480766         True
# 9  0.13572698        False

# %% [markdown]
# Pairwise comparison of topics

# %%
topic_results = bootstrap_pairwise(iv2)
topic_results
# Out:
#                       comparison    ci_lower    ci_upper  significant
# 0                User - Panorama -0.70716533 -0.19182485         True
# 1                  User - Inland -1.20441198 -0.65119642         True
# 2           User - International -1.04927544 -0.46552973         True
# 3                     User - Web -0.71190173 -0.14348093         True
# 4              User - Wirtschaft -1.37508005 -0.82148084         True
# 5                   User - Sport -1.21263136 -0.62322162         True
# 6                    User - Etat -1.29299912 -0.46320122         True
# 7            User - Wissenschaft  0.05185148  0.80122413         True
# 8                  User - Kultur -0.43925862  0.43294633        False
# 9              Panorama - Inland -0.66518119 -0.37068428         True
# 10      Panorama - International -0.49079587 -0.20178024         True
# 11                Panorama - Web -0.23081335  0.12490768        False
# 12         Panorama - Wirtschaft -0.77264346 -0.51359444         True
# 13              Panorama - Sport -0.67831568 -0.31063460         True
# 14               Panorama - Etat -0.74377430 -0.16665312         True
# 15       Panorama - Wissenschaft  0.53117072  1.13427284         True
# 16             Panorama - Kultur -0.00606979  0.79556039        False
# 17        Inland - International  0.01906655  0.32566607         True
# 18                  Inland - Web  0.29279943  0.63303575         True
# 19           Inland - Wirtschaft -0.27848738  0.00386269        False
# 20                Inland - Sport -0.20939627  0.21505833        False
# 21                 Inland - Etat -0.20430921  0.36064701        False
# 22         Inland - Wissenschaft  1.10391084  1.68007247         True
# 23               Inland - Kultur  0.52372817  1.35393463         True
# 24           International - Web  0.09779950  0.46089295         True
# 25    International - Wirtschaft -0.45594209 -0.15534144         True
# 26         International - Sport -0.37924573  0.11962756        False
# 27          International - Etat -0.42947535  0.22750314        False
# 28  International - Wissenschaft  0.95298984  1.48247374         True
# 29        International - Kultur  0.35790284  1.16359897         True
# 30              Web - Wirtschaft -0.76953291 -0.43888972         True
# 31                   Web - Sport -0.70618841 -0.20273609         True
# 32                    Web - Etat -0.69748890 -0.11211207         True
# 33            Web - Wissenschaft  0.61237464  1.25834767         True
# 34                  Web - Kultur  0.02803200  0.84383099         True
# 35            Wirtschaft - Sport -0.06400767  0.37021289        False
# 36             Wirtschaft - Etat -0.09792928  0.50886680        False
# 37     Wirtschaft - Wissenschaft  1.22177864  1.78850676         True
# 38           Wirtschaft - Kultur  0.64247969  1.57087027         True
# 39                  Sport - Etat -0.25156730  0.40664950        False
# 40          Sport - Wissenschaft  1.01305847  1.71909924         True
# 41                Sport - Kultur  0.44232707  1.31661926         True
# 42           Etat - Wissenschaft  0.92897684  1.73049033         True
# 43                 Etat - Kultur  0.34588980  1.35967882         True
# 44         Wissenschaft - Kultur -0.93594837  0.07431371        False
