# %%
import sqlite3
import pandas as pd
import numpy as np
import torch
from bs4 import BeautifulSoup
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
con = sqlite3.connect('../dataset/corpus.sqlite3')
model_path = "visegradmedia-emotion/Emotion_RoBERTa_german6_v7"

if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps" # For Mac M1/M2/M3
else:
    device = "cpu"

print(f"Using device: {device}")

batch_size = 32 if device != 'cpu' else 16
overlap = 64
# Out:
# Using device: cuda

# %%
max_length = 512
labels = {
    "LABEL_0": "Anger",
    "LABEL_1": "Fear",
    "LABEL_2": "Disgust",
    "LABEL_3": "Sadness",
    "LABEL_4": "Joy",
    "LABEL_5": "None"
}
emotions = list(labels.values())
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)
model.to(device)
model.eval()
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# XLMRobertaForSequenceClassification(
#   (classifier): XLMRobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=6, bias=True)
#   )
#   (roberta): XLMRobertaModel(
#     (embeddings): XLMRobertaEmbeddings(
#       (word_embeddings): Embedding(250002, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#     )
#     (encoder): XLMRobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x XLMRobertaLayer(
#           (attention): XLMRobertaAttention(
#             (self): XLMRobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): XLMRobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): XLMRobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): XLMRobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
# )

# %%
def chunk_text(df, text_col):
    df[text_col] = df[text_col].str.strip()
    chunked_rows = []
    for _, row in df.iterrows():
        text = str(row[text_col])
        token_ids = tokenizer.encode(text, add_special_tokens=False)

        start = 0
        while start < len(token_ids):
            end = start + max_length
            chunk_ids = token_ids[start:end]
            chunk_text = tokenizer.decode(chunk_ids)

            chunk_row = row.copy()
            chunk_row[text_col] = chunk_text
            chunked_rows.append(chunk_row)

            if end >= len(token_ids):
                break
            start += max_length - overlap
    return pd.DataFrame(chunked_rows).reset_index(drop=True)

# %%
def sentiment_analysis(df, column):
    all_scores = []
    model.to(device)
    label_names = [labels[f"LABEL_{i}"] for i in range(len(labels))]
    
    for b in range(0, len(df), batch_size):
        batch_texts = df[column].iloc[b:b + batch_size].tolist()

        inputs = tokenizer(
            batch_texts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=max_length,
            add_special_tokens=True
        ).to(device)

        outputs = model(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"])
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        
        all_scores.append(probs.cpu().detach().numpy())

    if all_scores:
        all_scores_np = np.vstack(all_scores)
        df_scores = pd.DataFrame(all_scores_np, columns=label_names)
        return pd.concat([df.reset_index(drop=True), df_scores], axis=1)
    else:
        return df

# %%
def combine_chunks(df, text_col, group_col, metadata_cols):
    df['chunk_tokens'] = df[text_col].apply(
        lambda x: len(tokenizer.encode(str(x), add_special_tokens=False))
    )

    # Multiply scores by weights
    weighted_cols = []
    for emo in emotions:
        df[f'{emo}_weighted'] = df[emo] * df['chunk_tokens']
        weighted_cols.append(f'{emo}_weighted')
    
    # Group and sum
    grouped = df.groupby(group_col)
    sums = grouped[weighted_cols + ['chunk_tokens']].sum()
    
    # Divide by total tokens to get weighted average
    result = pd.DataFrame(index=sums.index)
    for emo in emotions:
        result[emo] = sums[f'{emo}_weighted'] / sums['chunk_tokens']

    # Determine dominant emotion
    result['dominant_emotion'] = result[emotions].idxmax(axis=1)
    
    # Merge back
    # Get metadata from the original df (take the first occurrence per group)
    cols_to_select = metadata_cols.copy()
    if group_col not in cols_to_select:
        cols_to_select.append(group_col)
        
    meta_df = df[cols_to_select].drop_duplicates(subset=group_col).set_index(group_col)
    
    return result.join(meta_df).reset_index()

# %%
def descriptive_statistics(df):
    topic_dict = {}
    for topic, group in df.groupby('NewsroomTopic'):
        descriptives = {}
        for e in labels.values():
            descriptives[f"{e}_mean"] = group[e].mean()
            descriptives[f"{e}_std"] = group[e].std()
        topic_dict[topic] = descriptives
        
    table = pd.DataFrame.from_dict(topic_dict, orient='index')
    return table.reset_index().rename(columns={'index': 'NewsroomTopic'})

# %% [markdown]
# # Articles preprocessing

# %%
articles = pd.read_sql_query("SELECT * FROM Articles", con)
articles_meta = ['ID_Article', 'publishingDate', 'NewsroomTopic']
articles['body_text'] = articles.apply(
    lambda row: str(row['Title']) + " " +
    BeautifulSoup(str(row['Body']), "html.parser").get_text(),
    axis=1)
articles
# Out:
#        ID_Article                                              Path  \
# 0               1                           Newsroom/User/Community
# 1               2                    Newsroom/User/Community/Regeln
# 2               3                                    Diverses/mobil
# 3               4                  Newsroom/User/mitmachen/Mitreden
# 4               5                  Newsroom/User/mitmachen/Mitreden
# ...           ...                                               ...
# 12082       12083                       Newsroom/Kultur/Musikkultur
# 12083       12084                      Newsroom/Etat/PRINT/Springer
# 12084       12085                              Meinung/Kolumnen/rau
# 12085       12086                            Newsroom/Kultur/Buehne
# 12086       12087  Newsroom/Kultur/Kulturpolitik/Restitutionsfragen
#
#                publishingDate  \
# 0      2012-05-26 03:00:19.23
# 1      2012-05-26 12:12:19.46
# 2      2013-11-22 12:15:00.00
# 3      2014-08-13 05:30:00.00
# 4      2014-08-27 12:27:01.09
# ...                       ...
# 12082  2016-05-31 16:14:13.00
# 12083  2016-05-31 17:39:29.00
# 12084  2016-05-31 17:34:54.00
# 12085  2016-05-31 18:08:20.00
# 12086  2016-05-31 15:46:08.00
#
#                                                    Title  \
# 0                      Die Newsletter von derStandard.at
# 1                    Werden Sie Teil von derStandard.at!
# 2                     Die Android App von derStandard.at
# 3      Welche Erfahrungen haben Sie als Linkshänder g...
# 4                    Wie haben Sie das Jahr 1989 erlebt?
# ...                                                  ...
# 12082          Max Prosa: Junger Troubadour alter Schule
# 12083         "Können Adblocker nicht einfach hinnehmen"
# 12084           Die Rechten machen Facebook zum Hatebook
# 12085  "Wrestling Rita": Feministischer Punktsieg im ...
# 12086           Leopold-Museum feuert Provenienzforscher
#
#                                                     Body  \
# 0      <div class="section" id="content-main" itempro...
# 1      <div class="diashow" id="objectContent"><meta ...
# 2      <div class="section" id="content-main" itempro...
# 3      <div class="section" id="content-main" itempro...
# 4      <div class="section" id="content-main" itempro...
# ...                                                  ...
# 12082  <div class="section" id="content-main" itempro...
# 12083  <div class="section" id="content-main" itempro...
# 12084  <div class="section" id="content-main" itempro...
# 12085  <div class="section" id="content-main" itempro...
# 12086  <div class="section" id="content-main" itempro...
#
#                                                body_text
# 0      Die Newsletter von derStandard.at Abonnieren S...
# 1      Werden Sie Teil von derStandard.at! Werden Sie...
# 2      Die Android App von derStandard.at Die Smartph...
# 3      Welche Erfahrungen haben Sie als Linkshänder g...
# 4      Wie haben Sie das Jahr 1989 erlebt? Erzählen S...
# ...                                                  ...
# 12082  Max Prosa: Junger Troubadour alter Schule Von ...
# 12083  "Können Adblocker nicht einfach hinnehmen" Med...
# 12084  Die Rechten machen Facebook zum Hatebook Die F...
# 12085  "Wrestling Rita": Feministischer Punktsieg im ...
# 12086  Leopold-Museum feuert Provenienzforscher Rober...
#
# [12087 rows x 6 columns]

# %%
articles['MainPath'] = articles['Path'].apply(lambda x: str(x).split('/')[0])
articles = articles[articles['MainPath'] == 'Newsroom'].copy()
articles['NewsroomTopic'] = articles['Path'].apply(lambda x: str(x).split('/')[1])

#We dont care about user posts, only real jouranlists
articles = articles.drop(articles[articles['NewsroomTopic']=="User"].index)

articles = articles.loc[~articles['Title'].str.contains('derStandard.at', case=False, na=False)]

articles['num_tokens'] = articles['body_text'].apply(lambda x: len(tokenizer.encode(str(x), add_special_tokens=False)))
articles = articles[articles['num_tokens'] >= overlap]

articles = articles[['ID_Article', 'publishingDate', 'body_text', 'NewsroomTopic']]
articles
# Out:
#        ID_Article          publishingDate  \
# 9              10  2015-02-07 17:00:00.00
# 11             12  2015-03-20 15:11:50.00
# 14             15  2015-05-31 12:17:05.01
# 15             16  2015-05-31 12:09:51.00
# 17             18  2015-05-31 20:58:40.00
# ...           ...                     ...
# 12080       12081  2016-05-31 17:07:43.00
# 12082       12083  2016-05-31 16:14:13.00
# 12083       12084  2016-05-31 17:39:29.00
# 12085       12086  2016-05-31 18:08:20.00
# 12086       12087  2016-05-31 15:46:08.00
#
#                                                body_text  NewsroomTopic
# 9      Community-Quiz #2: Können Sie die Postings in ...   Wissenschaft
# 11     Android Auto geht in den USA an den Start Zuge...            Web
# 14     US-Außenminister Kerry nach Fahrradunfall im K...  International
# 15     Hundefleisch wird in Südkorea immer unbeliebte...       Panorama
# 17     FPÖ bei pessimistischen Steirern am stärksten ...         Inland
# ...                                                  ...            ...
# 12080  Niederösterreich: Zollfahnder beschlagnahmten ...       Panorama
# 12082  Max Prosa: Junger Troubadour alter Schule Von ...         Kultur
# 12083  "Können Adblocker nicht einfach hinnehmen" Med...           Etat
# 12085  "Wrestling Rita": Feministischer Punktsieg im ...         Kultur
# 12086  Leopold-Museum feuert Provenienzforscher Rober...         Kultur
#
# [10135 rows x 4 columns]

# %%
articles = chunk_text(articles, 'body_text')
articles
# Out:
#        ID_Article          publishingDate  \
# 0              10  2015-02-07 17:00:00.00
# 1              12  2015-03-20 15:11:50.00
# 2              15  2015-05-31 12:17:05.01
# 3              16  2015-05-31 12:09:51.00
# 4              16  2015-05-31 12:09:51.00
# ...           ...                     ...
# 18742       12084  2016-05-31 17:39:29.00
# 18743       12084  2016-05-31 17:39:29.00
# 18744       12086  2016-05-31 18:08:20.00
# 18745       12086  2016-05-31 18:08:20.00
# 18746       12087  2016-05-31 15:46:08.00
#
#                                                body_text  NewsroomTopic
# 0      Community-Quiz #2: Können Sie die Postings in ...   Wissenschaft
# 1      Android Auto geht in den USA an den Start Zuge...            Web
# 2      US-Außenminister Kerry nach Fahrradunfall im K...  International
# 3      Hundefleisch wird in Südkorea immer unbeliebte...       Panorama
# 4      nen. Für Kang Dae-in ist das koreanische Leibg...       Panorama
# ...                                                  ...            ...
# 18742  Hier ist ein signifikanter sechsstelliger Betr...           Etat
# 18743  auf rund 3,3 Milliarden Euro. Das digitale Ges...           Etat
# 18744  "Wrestling Rita": Feministischer Punktsieg im ...         Kultur
# 18745  "Humungus" Hradil, Mitbegründer der Wrestling ...         Kultur
# 18746  Leopold-Museum feuert Provenienzforscher Rober...         Kultur
#
# [18747 rows x 4 columns]

# %%
articles = sentiment_analysis(articles, 'body_text')
articles
# Out:
#        ID_Article          publishingDate  \
# 0              10  2015-02-07 17:00:00.00
# 1              12  2015-03-20 15:11:50.00
# 2              15  2015-05-31 12:17:05.01
# 3              16  2015-05-31 12:09:51.00
# 4              16  2015-05-31 12:09:51.00
# ...           ...                     ...
# 18742       12084  2016-05-31 17:39:29.00
# 18743       12084  2016-05-31 17:39:29.00
# 18744       12086  2016-05-31 18:08:20.00
# 18745       12086  2016-05-31 18:08:20.00
# 18746       12087  2016-05-31 15:46:08.00
#
#                                                body_text  NewsroomTopic  \
# 0      Community-Quiz #2: Können Sie die Postings in ...   Wissenschaft
# 1      Android Auto geht in den USA an den Start Zuge...            Web
# 2      US-Außenminister Kerry nach Fahrradunfall im K...  International
# 3      Hundefleisch wird in Südkorea immer unbeliebte...       Panorama
# 4      nen. Für Kang Dae-in ist das koreanische Leibg...       Panorama
# ...                                                  ...            ...
# 18742  Hier ist ein signifikanter sechsstelliger Betr...           Etat
# 18743  auf rund 3,3 Milliarden Euro. Das digitale Ges...           Etat
# 18744  "Wrestling Rita": Feministischer Punktsieg im ...         Kultur
# 18745  "Humungus" Hradil, Mitbegründer der Wrestling ...         Kultur
# 18746  Leopold-Museum feuert Provenienzforscher Rober...         Kultur
#
#           Anger      Fear   Disgust   Sadness       Joy      None
# 0      0.026524  0.019860  0.000412  0.001565  0.016253  0.935386
# 1      0.011033  0.000790  0.000114  0.000590  0.009938  0.977536
# 2      0.112814  0.004223  0.001938  0.058318  0.003376  0.819331
# 3      0.000044  0.999874  0.000018  0.000027  0.000012  0.000025
# 4      0.000063  0.999839  0.000033  0.000020  0.000014  0.000031
# ...         ...       ...       ...       ...       ...       ...
# 18742  0.000188  0.999511  0.000014  0.000031  0.000024  0.000232
# 18743  0.046454  0.016544  0.000133  0.005761  0.005960  0.925147
# 18744  0.026282  0.969194  0.001090  0.001196  0.000115  0.002123
# 18745  0.695503  0.030447  0.002946  0.012074  0.001049  0.257980
# 18746  0.499321  0.110607  0.000751  0.007877  0.001192  0.380252
#
# [18747 rows x 10 columns]

# %%
articles = combine_chunks(articles, 'body_text', 'ID_Article', articles_meta)
articles
# Out:
#        ID_Article     Anger      Fear   Disgust   Sadness       Joy      None  \
# 0              10  0.026524  0.019860  0.000412  0.001565  0.016253  0.935386
# 1              12  0.011033  0.000790  0.000114  0.000590  0.009938  0.977536
# 2              15  0.112814  0.004223  0.001938  0.058318  0.003376  0.819331
# 3              16  0.000049  0.999857  0.000029  0.000023  0.000014  0.000027
# 4              18  0.000110  0.999350  0.000016  0.000111  0.000052  0.000362
# ...           ...       ...       ...       ...       ...       ...       ...
# 10130       12081  0.679480  0.104902  0.029647  0.004698  0.002477  0.178796
# 10131       12083  0.071449  0.541087  0.000829  0.081418  0.002716  0.302501
# 10132       12084  0.002525  0.948069  0.000018  0.000341  0.000330  0.048716
# 10133       12086  0.216954  0.701730  0.001619  0.004295  0.000381  0.075021
# 10134       12087  0.499321  0.110607  0.000751  0.007877  0.001192  0.380252
#
#       dominant_emotion          publishingDate  NewsroomTopic
# 0                 None  2015-02-07 17:00:00.00   Wissenschaft
# 1                 None  2015-03-20 15:11:50.00            Web
# 2                 None  2015-05-31 12:17:05.01  International
# 3                 Fear  2015-05-31 12:09:51.00       Panorama
# 4                 Fear  2015-05-31 20:58:40.00         Inland
# ...                ...                     ...            ...
# 10130            Anger  2016-05-31 17:07:43.00       Panorama
# 10131             Fear  2016-05-31 16:14:13.00         Kultur
# 10132             Fear  2016-05-31 17:39:29.00           Etat
# 10133             Fear  2016-05-31 18:08:20.00         Kultur
# 10134            Anger  2016-05-31 15:46:08.00         Kultur
#
# [10135 rows x 10 columns]

# %%
articles[list(labels.values())].agg(['mean', 'std', 'min', 'max'])
# Out:
#          Anger      Fear   Disgust   Sadness       Joy      None
# mean  0.113015  0.554797  0.006669  0.026339  0.017419  0.281760
# std   0.179113  0.423640  0.042703  0.098663  0.087125  0.333720
# min   0.000024  0.000035  0.000008  0.000013  0.000010  0.000018
# max   0.973096  0.999905  0.969769  0.999524  0.999088  0.996742

# %%
articles['dominant_emotion'].value_counts()
# Out:
# dominant_emotion
# Fear       6038
# None       2986
# Anger       784
# Sadness     170
# Joy         119
# Disgust      38
# Name: count, dtype: int64

# %%
descriptive_statistics(articles)
# Out:
#    NewsroomTopic  Anger_mean  Anger_std  Fear_mean  Fear_std  Disgust_mean  \
# 0           Etat    0.155839   0.227160   0.387728  0.419714      0.006657
# 1         Inland    0.148231   0.205762   0.580644  0.402620      0.001147
# 2  International    0.096699   0.147509   0.650875  0.394930      0.007968
# 3         Kultur    0.097512   0.187936   0.589523  0.424829      0.006045
# 4       Panorama    0.093293   0.146290   0.657509  0.387529      0.023849
# 5          Sport    0.099148   0.136696   0.262946  0.360811      0.001497
# 6            Web    0.112335   0.195938   0.565411  0.431577      0.002160
# 7     Wirtschaft    0.154349   0.210733   0.550174  0.421505      0.000431
# 8   Wissenschaft    0.049203   0.112292   0.713364  0.395246      0.002069
#
#    Disgust_std  Sadness_mean  Sadness_std  Joy_mean   Joy_std  None_mean  \
# 0     0.049896      0.026404     0.096824  0.020487  0.092720   0.402885
# 1     0.007500      0.006992     0.046380  0.007355  0.050355   0.255631
# 2     0.039550      0.018428     0.073209  0.003293  0.021249   0.222738
# 3     0.035044      0.086073     0.218834  0.018774  0.089559   0.202074
# 4     0.085822      0.034348     0.112037  0.009914  0.075088   0.181086
# 5     0.010355      0.070583     0.138174  0.076379  0.177909   0.489448
# 6     0.019601      0.006040     0.041599  0.012550  0.066053   0.301503
# 7     0.000928      0.006895     0.038790  0.003407  0.024152   0.284745
# 8     0.011930      0.013024     0.055552  0.012303  0.076752   0.210036
#
#    None_std
# 0  0.378780
# 1  0.317454
# 2  0.292611
# 3  0.315493
# 4  0.250251
# 5  0.336430
# 6  0.363543
# 7  0.325786
# 8  0.321820

# %% [markdown]
# # Comments

# %%
posts = pd.read_sql_query("SELECT * FROM Posts", con)
posts_meta = ['ID_Post', 'ID_Article', 'CreatedAt', 'NewsroomTopic']
posts['NewsroomTopic'] = posts['ID_Article'].map(articles.set_index('ID_Article')['NewsroomTopic'])
posts
# Out:
#          ID_Post  ID_Parent_Post  ID_Article  ID_User  \
# 0              1             NaN           1     9089
# 1              2             NaN           1    29367
# 2              3             2.0           1     5095
# 3              4             3.0           1     1682
# 4              5             NaN           1     3343
# ...          ...             ...         ...      ...
# 1011768  1011769       1011764.0       12087     6355
# 1011769  1011770       1011765.0       12087     6355
# 1011770  1011771       1011770.0       12087    27023
# 1011771  1011772       1011769.0       12087    19159
# 1011772  1011773       1011768.0       12087     8696
#
#                        CreatedAt   Status                   Headline  \
# 0        2003-04-23 14:52:41.870  deleted
# 1        2003-11-04 16:21:57.850   online  Newsletter "DER STANDARD"
# 2        2004-01-28 12:57:28.240  deleted         Auch begeistert...
# 3        2004-02-03 20:32:39.123  deleted            Abmeldeprobleme
# 4        2004-03-02 11:37:44.100   online
# ...                          ...      ...                        ...
# 1011768  2016-06-01 23:10:29.003   online                       None
# 1011769  2016-06-01 23:11:14.790   online                       None
# 1011770  2016-06-02 08:16:56.690   online                       None
# 1011771  2016-06-02 09:12:09.993   online                       None
# 1011772  2016-06-02 09:52:03.410   online          Elisabeth Leopold
#
#                                                       Body  PositiveVotes  \
# 0                                                                       0
# 1        Ich bin begeistert von den STANDARD - Newslett...              0
# 2        ... Aber momentan funktioniert das Abmelden od...              0
# 3        Es ist ganz einfach nervend!\r\nVor kurzem hab...              0
# 4         und sie als mitarbeiter sind natuerlich objektiv              0
# ...                                                    ...            ...
# 1011768  zwischen der beendigung eines arbeitsverhältni...              0
# 1011769  du sagst es ja im namen selbst: wegen eindicku...              1
# 1011770  Was genau haben Sie denn nicht verstanden? Ich...              0
# 1011771  irgendwie widersprechen Sie sich in Ihrem Post...              1
# 1011772  Ohne sie läuft doch weiterhin gar nichts im Le...              0
#
#          NegativeVotes NewsroomTopic
# 0                    0           NaN
# 1                    0           NaN
# 2                    0           NaN
# 3                    0           NaN
# 4                    0           NaN
# ...                ...           ...
# 1011768              0        Kultur
# 1011769              0        Kultur
# 1011770              1        Kultur
# 1011771              0        Kultur
# 1011772              0        Kultur
#
# [1011773 rows x 11 columns]

# %%
posts = posts[posts['ID_Article'].isin(articles['ID_Article'])]
posts = posts.dropna(subset=['Body','NewsroomTopic'])
posts = posts[posts['Body'].astype(str).str.strip() != '']
posts = posts[posts['ID_Parent_Post'].isna()]
posts = posts[['ID_Post','ID_Article','CreatedAt','Body', 'NewsroomTopic']]
posts
# Out:
#          ID_Post  ID_Article                CreatedAt  \
# 2083        2084          10  2015-02-07 17:11:43.933
# 2085        2086          10  2015-02-07 17:29:14.757
# 2087        2088          10  2015-02-07 17:30:52.763
# 2090        2091          10  2015-02-07 17:44:51.023
# 2091        2092          10  2015-02-07 17:55:30.990
# ...          ...         ...                      ...
# 1010993  1010994       12083  2016-05-31 17:36:21.730
# 1010994  1010995       12083  2016-06-01 05:24:53.540
# 1010996  1010997       12084  2016-05-31 17:54:24.000
# 1011759  1011760       12086  2016-05-31 21:10:42.487
# 1011760  1011761       12087  2016-05-31 22:10:11.207
#
#                                                       Body NewsroomTopic
# 2083                         ich soll also mehr mitposten.  Wissenschaft
# 2085                                         Höhö 7 von 10  Wissenschaft
# 2087     Buh, 1 Prozent unter dem Durchschnitt. Ein Glü...  Wissenschaft
# 2090                              8 von 10. Alles geraten.  Wissenschaft
# 2091                         die fpö hat mich rausgerissen  Wissenschaft
# ...                                                    ...           ...
# 1010993  "Singer-Songwriter" ist keine Neuerfindung des...        Kultur
# 1010994  Bei ordentlichen medien gibts dann immer einen...        Kultur
# 1010996  Die User haben hier, haben es doch oft formuli...          Etat
# 1011759                                   Na ja. Und wozu?        Kultur
# 1011760  frau kronsteiner muss einen artikel über ein t...        Kultur
#
# [249993 rows x 5 columns]

# %%
posts = sentiment_analysis(posts,'Body')
posts['dominant_emotion'] = posts[emotions].idxmax(axis=1)
posts
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 posts = sentiment_analysis(posts,'Body')
#       2 posts['dominant_emotion'] = posts[emotions].idxmax(axis=1)
#       3 posts
#
# Cell In[5], line 21, in sentiment_analysis(df, column)
#      18     outputs = model(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"])
#      19     probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
# ---> 21     all_scores.append(probs.cpu().detach().numpy())
#      23 if all_scores:
#      24     all_scores_np = np.vstack(all_scores)
#
# KeyboardInterrupt:

# %%
posts[list(labels.values())].agg(['mean', 'std', 'min', 'max'])
# Out:
#          Anger      Fear   Disgust   Sadness       Joy      None
# mean  0.491233  0.213216  0.013411  0.023097  0.030817  0.228227
# std   0.426120  0.390424  0.097055  0.109475  0.150872  0.343662
# min   0.000022  0.000006  0.000007  0.000011  0.000008  0.000014
# max   0.997274  0.999910  0.999890  0.999747  0.999763  0.998005

# %%
posts['dominant_emotion'].value_counts()
# Out:
# dominant_emotion
# Anger      67760
# None       28543
# Fear       28233
# Joy         3767
# Sadness     2251
# Disgust     1567
# Name: count, dtype: int64

# %%
descriptive_statistics(posts)
# Out:
#    NewsroomTopic  Anger_mean  Anger_std  Fear_mean  Fear_std  Disgust_mean  \
# 0           Etat    0.504402   0.426727   0.186374  0.370279      0.025247
# 1         Inland    0.516361   0.428303   0.206627  0.386210      0.011430
# 2  International    0.497490   0.426647   0.229763  0.400815      0.012268
# 3         Kultur    0.425920   0.424721   0.178754  0.366872      0.017802
# 4       Panorama    0.473676   0.426083   0.240642  0.408875      0.017516
# 5          Sport    0.485871   0.418484   0.130685  0.318983      0.009695
# 6           User    0.438504   0.424003   0.235944  0.406490      0.018902
# 7            Web    0.459208   0.422017   0.203926  0.382629      0.015293
# 8     Wirtschaft    0.524120   0.424994   0.204208  0.382210      0.007894
# 9   Wissenschaft    0.406580   0.415734   0.256275  0.420847      0.018971
#
#    Disgust_std  Sadness_mean  Sadness_std  Joy_mean   Joy_std  None_mean  \
# 0     0.139414      0.023276     0.115130  0.032983  0.160980   0.227719
# 1     0.089975      0.021041     0.103512  0.025750  0.136413   0.218790
# 2     0.089718      0.021421     0.104662  0.021320  0.124565   0.217739
# 3     0.108524      0.051453     0.177733  0.079928  0.244519   0.246143
# 4     0.111090      0.025044     0.115429  0.025500  0.137973   0.217623
# 5     0.077482      0.034133     0.128040  0.059614  0.205682   0.280003
# 6     0.120365      0.039579     0.155240  0.051317  0.199677   0.215754
# 7     0.106449      0.018432     0.094796  0.042992  0.178551   0.260149
# 8     0.073192      0.017550     0.093490  0.026220  0.138090   0.220008
# 9     0.118306      0.026145     0.114907  0.036376  0.163246   0.255653
#
#    None_std
# 0  0.346766
# 1  0.339531
# 2  0.338059
# 3  0.357440
# 4  0.337459
# 5  0.363363
# 6  0.335665
# 7  0.360851
# 8  0.337619
# 9  0.357227

# %% [markdown]
# Prepare File

# %%
articles.rename(columns={
    "Anger": "anger_a",
    "Fear": "fear_a",
    "Disgust": "disgust_a",
    "Sadness": "sadness_a",
    "Joy": "joy_a",
    "None": "none_a",
    "dominant_emotion": "dominant_emotion_a"
}, inplace=True)

posts.rename(columns={
    "Anger": "anger_p",
    "Fear": "fear_p",
    "Disgust": "disgust_p",
    "Sadness": "sadness_p",
    "Joy": "joy_p",
    "None": "none_p",
    "dominant_emotion": "dominant_emotion_p"
}, inplace=True)

data = pd.merge(articles, posts, on=["ID_Article", "NewsroomTopic"], how="right")
data["publishingDate"] = pd.to_datetime(data['publishingDate'])
data["CreatedAt"] = pd.to_datetime(data['CreatedAt'])

data = data[["ID_Post" ,"CreatedAt", "anger_p", "fear_p", "disgust_p", "sadness_p", "joy_p", "none_p", "dominant_emotion_p", "NewsroomTopic",
             "ID_Article", "publishingDate", "anger_a", "fear_a", "disgust_a", "sadness_a", "joy_a", "none_a", "dominant_emotion_a"]]
data
# Out:
#         ID_Post               CreatedAt   anger_p    fear_p  disgust_p  \
# 0           191 2014-08-13 06:29:59.987  0.000120  0.999689   0.000045
# 1           197 2014-08-13 07:23:13.860  0.989551  0.000133   0.000688
# 2           198 2014-08-13 07:26:24.743  0.108701  0.002560   0.018449
# 3           201 2014-08-13 07:33:33.407  0.430212  0.008964   0.002008
# 4           202 2014-08-13 07:34:11.377  0.981684  0.000288   0.000668
# ...         ...                     ...       ...       ...        ...
# 132116  1010856 2016-06-02 08:20:08.213  0.325956  0.000242   0.000464
# 132117  1010859 2016-06-02 13:55:13.073  0.072507  0.066935   0.003864
# 132118  1010871 2016-05-31 22:56:09.220  0.386056  0.000832   0.000550
# 132119  1011763 2016-05-31 23:47:32.010  0.995209  0.000364   0.000361
# 132120  1011773 2016-06-02 09:52:03.410  0.781505  0.000223   0.000374
#
#         sadness_p     joy_p    none_p dominant_emotion_p NewsroomTopic  \
# 0        0.000047  0.000020  0.000079               Fear          User
# 1        0.000847  0.000460  0.008320              Anger          User
# 2        0.005487  0.001450  0.863353               None          User
# 3        0.366200  0.002447  0.190168              Anger          User
# 4        0.001571  0.000484  0.015305              Anger          User
# ...           ...       ...       ...                ...           ...
# 132116   0.005642  0.053380  0.614316               None        Inland
# 132117   0.849980  0.000343  0.006371            Sadness        Inland
# 132118   0.003874  0.001406  0.607282               None           Web
# 132119   0.000621  0.000286  0.003159              Anger        Kultur
# 132120   0.011925  0.002562  0.203410              Anger        Kultur
#
#         ID_Article      publishingDate   anger_a    fear_a  disgust_a  \
# 0                4 2014-08-13 05:30:00  0.000047  0.999862   0.000017
# 1                4 2014-08-13 05:30:00  0.000047  0.999862   0.000017
# 2                4 2014-08-13 05:30:00  0.000047  0.999862   0.000017
# 3                4 2014-08-13 05:30:00  0.000047  0.999862   0.000017
# 4                4 2014-08-13 05:30:00  0.000047  0.999862   0.000017
# ...            ...                 ...       ...       ...        ...
# 132116       12078 2016-05-31 14:54:45  0.000040  0.999832   0.000011
# 132117       12078 2016-05-31 14:54:45  0.000040  0.999832   0.000011
# 132118       12079 2016-05-31 09:43:18  0.000158  0.999671   0.000029
# 132119       12087 2016-05-31 15:46:08  0.499322  0.110606   0.000751
# 132120       12087 2016-05-31 15:46:08  0.499322  0.110606   0.000751
#
#         sadness_a     joy_a    none_a dominant_emotion_a
# 0        0.000024  0.000017  0.000033               Fear
# 1        0.000024  0.000017  0.000033               Fear
# 2        0.000024  0.000017  0.000033               Fear
# 3        0.000024  0.000017  0.000033               Fear
# 4        0.000024  0.000017  0.000033               Fear
# ...           ...       ...       ...                ...
# 132116   0.000066  0.000021  0.000029               Fear
# 132117   0.000066  0.000021  0.000029               Fear
# 132118   0.000017  0.000025  0.000100               Fear
# 132119   0.007877  0.001192  0.380252              Anger
# 132120   0.007877  0.001192  0.380252              Anger
#
# [132121 rows x 19 columns]

# %%
data.to_csv("../dataset/combined_sentiments.csv", index=False)
